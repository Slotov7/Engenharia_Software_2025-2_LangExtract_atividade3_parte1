# %% [markdown]
# <a href="https://colab.research.google.com/github/Slotov7/Engenharia_Software_2025-2_LangExtract_atividade3_parte1/blob/master/Tarefa_A_Dupla_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise de Ferramentas de CI/CD do Projeto
#
# ## 1 Ferramentas de CI/CD Identificadas
#
# O projeto utiliza **exclusivamente o GitHub Actions** como ferramenta de automação de **CI/CD**.
#
# - Não foram encontrados arquivos de configuração de outras ferramentas como:
#   - Jenkins
#   - Travis CI
#   - CircleCI
# - Isso indica uma infraestrutura **centralizada no ecossistema do GitHub**, reduzindo complexidade operacional e facilitando manutenção.
#
# ---
#
# ## 2 Evidências Encontradas (Arquivos de Configuração)
#
# Foram identificados **11 workflows ativos** localizados no diretório:
#
# ```bash
# .github/workflows/
# ````
#
# Esses workflows cobrem diferentes etapas do ciclo de vida do projeto:
#
# ### Pipeline Principal
#
# * **`ci.yaml`**
#
#   * Responsável pelo fluxo principal de **Build & Test**
#   * Executa validações automáticas a cada push e/ou pull request
#
# ### Publicação e Releases
#
# * **`publish.yml`**
#
#   * Automatiza a publicação de pacotes
# * **`zenodo-publish.yml`**
#
#   * Responsável pelo registro acadêmico do projeto via **Zenodo**
#
# ### Controle de Qualidade de Pull Requests
#
# O projeto adota políticas rigorosas de qualidade automatizada:
#
# * **`check-pr-size.yml`**
#
#   * Verifica o tamanho dos Pull Requests
# * **`validate_pr_template.yaml`**
#
#   * Garante o uso correto do template de descrição
# * **`check-linked-issue.yml`**
#
#   * Obriga o vínculo do PR a uma issue existente
#
# ---
#
# ## 3️ Outras Ferramentas de Apoio
#
# Além dos workflows de CI/CD, o projeto utiliza ferramentas complementares para garantir qualidade e consistência do código:
#
# ###  Testes Automatizados
#
# * **`tox.ini`**
#
#   * Orquestra a execução de testes em múltiplos ambientes Python
#   * Facilita compatibilidade entre versões
#
# ###  Padronização de Código
#
# * **`.pre-commit-config.yaml`**
#
#   * Define ganchos de validação executados antes de cada commit
#   * Inclui checagens de estilo, formatação e boas práticas
#
# ---
#
# 📌 **Conclusão:**
# A combinação de **GitHub Actions**, **tox** e **pre-commit** demonstra uma abordagem madura de automação, qualidade e governança de código, alinhada com boas práticas modernas de engenharia de software.
